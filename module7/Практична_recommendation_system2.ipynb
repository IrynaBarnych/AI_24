# %% [markdown]
# <a href="https://colab.research.google.com/github/IrynaBarnych/AI_24/blob/lab/module7/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%BD%D0%B0_recommendation_system2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Завдання
#
# * замініть усі пропущені значення на пусті рядки
# * отримайте список з назвами фільмів
# * застосуйте TF-iDF до колонки `description`
# * на основі отриманих даних побудуйте таблицю з коефіцієнтами подібності
# * напишіть функцію яка отримує як аргемент назву фільму та число і повертає відповідну кількість найбільш схожих фільмів

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module7/data/netflix_titles.csv")

df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
df.fillna(value='', inplace=True)

df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans
# 4      s5  TV Show           Kota Factory
#
#                                                 cast        country  \
# 0                                                     United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
titles = df['title']

data = df.drop(columns=['title'])

# %%
titles
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
import pandas as pd

X = df['description']

vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(X)

X_train, X_test = train_test_split(X, train_size=0.8)

X_train.shape
# Out:
# (7045, 18895)

# %%
import sklearn.metrics.pairwise as pairwise

sim_matrix = pairwise.cosine_similarity

# %%
sim_matrix
# Out:
# array([[0.        , 0.18181818, 0.18181818, ..., 0.09090909, 0.09090909,
#         0.09090909],
#        [0.18181818, 0.        , 0.18181818, ..., 0.09090909, 0.09090909,
#         0.09090909],
#        [0.18181818, 0.18181818, 0.        , ..., 0.09090909, 0.09090909,
#         0.09090909],
#        ...,
#        [0.09090909, 0.09090909, 0.09090909, ..., 0.        , 0.        ,
#         0.        ],
#        [0.09090909, 0.09090909, 0.09090909, ..., 0.        , 0.        ,
#         0.        ],
#        [0.09090909, 0.09090909, 0.09090909, ..., 0.        , 0.        ,
#         0.        ]])

# %%
df_sim = pd.DataFrame(sim_matrix,
                      columns=titles,
                      index=titles)

df_sim.head()
# Out:
# title                                            Dick Johnson Is Dead  \
# title
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>
# Ganglands              <function cosine_similarity at 0x7d23289ed480>
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>
#
# title                                                   Blood & Water  \
# title
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>
# Ganglands              <function cosine_similarity at 0x7d23289ed480>
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>
#
# title                                                       Ganglands  \
# title
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>
# Ganglands              <function cosine_similarity at 0x7d23289ed480>
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>
#
# title                                           Jailbirds New Orleans  \
# title
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>
# Ganglands              <function cosine_similarity at 0x7d23289ed480>
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>
#
# title                                                    Kota Factory  \
# title
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>
# Ganglands              <function cosine_similarity at 0x7d23289ed480>
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>
#
# title                                                   Midnight Mass  \
# title
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>
# Ganglands              <function cosine_similarity at 0x7d23289ed480>
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>
#
# title                                My Little Pony: A New Generation  \
# title
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>
# Ganglands              <function cosine_similarity at 0x7d23289ed480>
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>
#
# title                                                         Sankofa  \
# title
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>
# Ganglands              <function cosine_similarity at 0x7d23289ed480>
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>
#
# title                                   The Great British Baking Show  \
# title
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>
# Ganglands              <function cosine_similarity at 0x7d23289ed480>
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>
#
# title                                                    The Starling  ...  \
# title                                                                  ...
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>  ...
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>  ...
# Ganglands              <function cosine_similarity at 0x7d23289ed480>  ...
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>  ...
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>  ...
#
# title                                                       Zak Storm  \
# title
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>
# Ganglands              <function cosine_similarity at 0x7d23289ed480>
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>
#
# title                                                        Zed Plus  \
# title
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>
# Ganglands              <function cosine_similarity at 0x7d23289ed480>
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>
#
# title                                                           Zenda  \
# title
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>
# Ganglands              <function cosine_similarity at 0x7d23289ed480>
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>
#
# title                                              Zindagi Gulzar Hai  \
# title
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>
# Ganglands              <function cosine_similarity at 0x7d23289ed480>
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>
#
# title                                                         Zinzana  \
# title
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>
# Ganglands              <function cosine_similarity at 0x7d23289ed480>
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>
#
# title                                                          Zodiac  \
# title
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>
# Ganglands              <function cosine_similarity at 0x7d23289ed480>
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>
#
# title                                                     Zombie Dumb  \
# title
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>
# Ganglands              <function cosine_similarity at 0x7d23289ed480>
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>
#
# title                                                      Zombieland  \
# title
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>
# Ganglands              <function cosine_similarity at 0x7d23289ed480>
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>
#
# title                                                            Zoom  \
# title
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>
# Ganglands              <function cosine_similarity at 0x7d23289ed480>
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>
#
# title                                                          Zubaan
# title
# Dick Johnson Is Dead   <function cosine_similarity at 0x7d23289ed480>
# Blood & Water          <function cosine_similarity at 0x7d23289ed480>
# Ganglands              <function cosine_similarity at 0x7d23289ed480>
# Jailbirds New Orleans  <function cosine_similarity at 0x7d23289ed480>
# Kota Factory           <function cosine_similarity at 0x7d23289ed480>
#
# [5 rows x 8807 columns]

# %%
df_sim.shape
# Out:
# (8807, 8807)

# %%
df_sim.to_csv('df_sim.csv')
